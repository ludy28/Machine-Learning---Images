# %% [markdown]
# <a href="https://colab.research.google.com/github/ludy28/Machine-Learning---Images/blob/main/Pandas_Car_details.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('car data.csv', index_col = 'Car_Name')

# %%
df.head()
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# sx4       2013           4.75           9.54       43000    Diesel
# ciaz      2017           7.25           9.85        6900    Petrol
# wagon r   2011           2.85           4.15        5200    Petrol
# swift     2014           4.60           6.87       42450    Diesel
#
#          Seller_Type Transmission  Owner
# Car_Name
# ritz          Dealer       Manual      0
# sx4           Dealer       Manual      0
# ciaz          Dealer       Manual      0
# wagon r       Dealer       Manual      0
# swift         Dealer       Manual      0

# %% [markdown]
# How many elements does the dataframe have?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301 entries, ritz to brio
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           301 non-null    int64
#  1   Selling_Price  301 non-null    float64
#  2   Present_Price  301 non-null    float64
#  3   Kms_Driven     301 non-null    int64
#  4   Fuel_Type      301 non-null    object
#  5   Seller_Type    301 non-null    object
#  6   Transmission   301 non-null    object
#  7   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 29.3+ KB

# %%
df.shape
# Out:
# (301, 8)

# %%
  df.loc['swift','Selling_Price']
# Out:
# Car_Name
# swift    4.60
# swift    3.00
# swift    4.15
# swift    6.00
# swift    4.95
# Name: Selling_Price, dtype: float64

# %%
df['Selling_Price'].max()
# Out:
# 35.0

# %%
df.max()
# Out:
# Year                   2018
# Selling_Price          35.0
# Present_Price          92.6
# Kms_Driven           500000
# Fuel_Type            Petrol
# Seller_Type      Individual
# Transmission         Manual
# Owner                     3
# dtype: object

# %%
df.loc[['ritz', 'swift']]
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# ritz      2012           3.10           5.98       51439    Diesel
# ritz      2011           2.35           4.89       54200    Petrol
# ritz      2013           2.65           4.89       64532    Petrol
# swift     2014           4.60           6.87       42450    Diesel
# swift     2011           3.00           4.99       20000    Petrol
# swift     2013           4.15           5.87       55138    Petrol
# swift     2017           6.00           6.49       16200    Petrol
# swift     2014           4.95           7.49       39000    Diesel
#
#          Seller_Type Transmission  Owner
# Car_Name
# ritz          Dealer       Manual      0
# ritz          Dealer       Manual      0
# ritz          Dealer       Manual      0
# ritz          Dealer       Manual      0
# swift         Dealer       Manual      0
# ...

# %%
df.sort_values(by = ['Year'], ascending  = True)
# Out:
#                            Year  Selling_Price  Present_Price  Kms_Driven  \
# Car_Name
# 800                        2003           0.35           2.28      127000
# sx4                        2003           2.25           7.98       62000
# corolla                    2004           1.50          12.35      135154
# innova                     2005           2.75          10.21       90000
# innova                     2005           3.49          13.46      197176
# ...                         ...            ...            ...         ...
# Royal Enfield Classic 350  2017           1.35           1.47        4100
# jazz                       2017           6.50           8.70       21200
# innova                     2017          19.75          23.15       11000
# TVS Apache RTR 160         2017           0.65           0.81       11800
# vitara brezza              2018           9.25           9.83        2071
#
#                           Fuel_Type Seller_Type Transmission  Owner
# ...

# %%
df.loc[df['Year'] == 2011]
# Out:
#                            Year  Selling_Price  Present_Price  Kms_Driven  \
# Car_Name
# wagon r                    2011           2.85          4.150        5200
# sx4                        2011           4.40          8.010       50000
# swift                      2011           3.00          4.990       20000
# ritz                       2011           2.35          4.890       54200
# sx4                        2011           2.95          7.740       49998
# corolla altis              2011           4.35         13.740       88000
# corolla altis              2011           4.50         12.480       45000
# etios liva                 2011           2.65          5.710       43000
# Royal Enfield Thunder 350  2011           1.05          1.500        6900
# TVS Apache RTR 180         2011           0.50          0.826        6000
# Bajaj Avenger Street 220   2011           0.45          0.950       24000
# ...

# %%
df['Year'].value_counts().head()
# Out:
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# Name: Year, dtype: int64

# %%
df.loc[df['Year'] == 2011].sort_values(by="Selling_Price")
# Out:
#                            Year  Selling_Price  Present_Price  Kms_Driven  \
# Car_Name
# Bajaj Discover 125         2011           0.15          0.570       35000
# Honda Karizma              2011           0.35          1.050       30000
# Hero Honda CBZ extreme     2011           0.38          0.787       75000
# Bajaj Avenger Street 220   2011           0.45          0.950       24000
# TVS Apache RTR 180         2011           0.50          0.826        6000
# Royal Enfield Thunder 350  2011           1.05          1.500        6900
# ritz                       2011           2.35          4.890       54200
# i10                        2011           2.55          4.430       57000
# etios liva                 2011           2.65          5.710       43000
# i10                        2011           2.70          4.600       22517
# wagon r                    2011           2.85          4.150        5200
# ...

# %%
df.loc[df['Year'] == 2011, 'Selling_Price'].min()
# Out:
# 0.15

# %%
df.loc[
    (df['Year'] == 2011) &
     (df['Selling_Price'] == df.loc[df['Year'] == 2011, 'Selling_Price'].min())

     ]
# Out:
#                     Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# Bajaj Discover 125  2011           0.15           0.57       35000    Petrol
#
#                    Seller_Type Transmission  Owner
# Car_Name
# Bajaj Discover 125  Individual       Manual      1

# %%
df.head()
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# sx4       2013           4.75           9.54       43000    Diesel
# ciaz      2017           7.25           9.85        6900    Petrol
# wagon r   2011           2.85           4.15        5200    Petrol
# swift     2014           4.60           6.87       42450    Diesel
#
#          Seller_Type Transmission  Owner
# Car_Name
# ritz          Dealer       Manual      0
# sx4           Dealer       Manual      0
# ciaz          Dealer       Manual      0
# wagon r       Dealer       Manual      0
# swift         Dealer       Manual      0

# %%
df['Ratio KM_SP'] = df['Kms_Driven'] /df['Selling_Price']

# %%
df.head()
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# sx4       2013           4.75           9.54       43000    Diesel
# ciaz      2017           7.25           9.85        6900    Petrol
# wagon r   2011           2.85           4.15        5200    Petrol
# swift     2014           4.60           6.87       42450    Diesel
#
#          Seller_Type Transmission  Owner  Ratio KM_SP
# Car_Name
# ritz          Dealer       Manual      0  8059.701493
# sx4           Dealer       Manual      0  9052.631579
# ciaz          Dealer       Manual      0   951.724138
# wagon r       Dealer       Manual      0  1824.561404
# swift         Dealer       Manual      0  9228.260870

# %%
df.query("Year == 2011").shape
# Out:
# (19, 9)

# %%
df['Ratio KM_SP'].describe()
# Out:
# count    3.010000e+02
# mean     4.158904e+04
# std      1.875299e+05
# min      1.818182e+02
# 25%      4.192137e+03
# 50%      9.007556e+03
# 75%      2.306383e+04
# max      2.941176e+06
# Name: Ratio KM_SP, dtype: float64

# %%
df.query("Selling_Price > 2.5")
# Out:
#           Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# ritz      2014           3.35           5.59       27000    Petrol
# sx4       2013           4.75           9.54       43000    Diesel
# ciaz      2017           7.25           9.85        6900    Petrol
# wagon r   2011           2.85           4.15        5200    Petrol
# swift     2014           4.60           6.87       42450    Diesel
# ...        ...            ...            ...         ...       ...
# city      2016           9.50          11.60       33988    Diesel
# brio      2015           4.00           5.90       60000    Petrol
# city      2009           3.35          11.00       87934    Petrol
# city      2017          11.50          12.50        9000    Diesel
# brio      2016           5.30           5.90        5464    Petrol
#
#          Seller_Type Transmission  Owner   Ratio KM_SP
# Car_Name
# ritz          Dealer       Manual      0   8059.701493
# ...

# %%
mean_SP = df['Selling_Price'].mean()
mean_SP
# Out:
# 4.661295681063123

# %%
df.query("Selling_Price > @mean_SP")
# Out:
#                Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# Car_Name
# sx4            2013           4.75           9.54       43000    Diesel
# ciaz           2017           7.25           9.85        6900    Petrol
# vitara brezza  2018           9.25           9.83        2071    Diesel
# ciaz           2015           6.75           8.12       18796    Petrol
# s cross        2015           6.50           8.61       33429    Diesel
# ...             ...            ...            ...         ...       ...
# jazz           2016           6.40           8.40       12000    Petrol
# city           2015           8.55          13.09       60076    Diesel
# city           2016           9.50          11.60       33988    Diesel
# city           2017          11.50          12.50        9000    Diesel
# brio           2016           5.30           5.90        5464    Petrol
#
#               Seller_Type Transmission  Owner  Ratio KM_SP
# Car_Name
# ...
